# %% [markdown]
# https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb#scrollTo=wbvMlHd_QwMG

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.6/78.2 GB disk)

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
base_path='/content/drive/MyDrive/Wire_Note_Project'

# %%
os.path.join(base_path,"try_yolov8.yaml")

# %%
model = YOLO(os.path.join(base_path,"yolov8m.pt"))
model.train(
    data=os.path.join(base_path,"try_yolov8.yaml"),
    epochs=300,
    imgsz=640,
)
metrics = model.val()
print("metrics--", metrics)
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...
