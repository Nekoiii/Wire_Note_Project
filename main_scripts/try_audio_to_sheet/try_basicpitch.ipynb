# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install basic-pitch

# %%
import os

# %%
base_path='/content/drive/MyDrive/Wire_Note_Project/try_audio_to_sheet'
output_path=os.path.join(base_path,'output')
os.makedirs(output_path, exist_ok=True)
# input_path=os.path.join(base_path,'test_audio.mp3')
input_path=os.path.join(base_path,'test_audio-2.mp3')
os.path.exists(input_path)
# Out:
# True

# %%
output_path
# os.path.exists(output_path)
# Out:
# '/content/drive/MyDrive/Wire_Note_Project/try_audio_to_sheet/output'

# %%
# *Dont't forget '{}' here !!!!
# !basic-pitch {output_path} {input_path}
# Out:
# ✨✨✨✨✨✨✨✨✨
# ✨ Basic Pitch  ✨
# ✨✨✨✨✨✨✨✨✨
#
# Importing Tensorflow (this may take a few seconds)...
#
# Predicting MIDI for /content/drive/MyDrive/Wire_Note_Project/try_audio_to_sheet/test_audio-2.mp3...
#
#
#   Creating midi...
#   💅 Saved to /content/drive/MyDrive/Wire_Note_Project/try_audio_to_sheet/output/test_audio-2_basic_pitch.mid
#
# ✨ Done ✨
