# %%
# !pip install basic-pitch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.5/373.5 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 23.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 6.7 MB/s eta 0:00:00
# ...
#   Created wheel for mir-eval: filename=mir_eval-0.7-py3-none-any.whl size=100703 sha256=1b9c06f8f8fdf166c052ab3600638f8f23a996c75cdf6f197a4396cd209d7110
#   Stored in directory: /root/.cache/pip/wheels/3e/2f/0d/dda9c4c77a170e21356b6afa2f7d9bb078338634ba05d94e3f
# ...
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592287 sha256=526fbfcc7aa1a2b1ca0a091a539a899774749a705c824cabebf6e908066ed508
# ...

# %%
import os

# %%
base_path='/content/drive/MyDrive/Wire_Note_Project/try_audio_to_sheet'
output_path=os.path.join(base_path,'output')
os.makedirs(output_path, exist_ok=True)
# input_path=os.path.join(base_path,'test_audio.mp3')
input_path=os.path.join(base_path,'output/musicgen_out-3.wav')
os.path.exists(input_path)
# Out:
# True

# %%
# *Dont't forget '{}' here !!!!
# !basic-pitch {output_path} {input_path}
# Out:
# ✨✨✨✨✨✨✨✨✨
# ✨ Basic Pitch  ✨
# ✨✨✨✨✨✨✨✨✨
#
# Importing Tensorflow (this may take a few seconds)...
#
# Predicting MIDI for /content/drive/MyDrive/Wire_Note_Project/try_audio_to_sheet/output/musicgen_out-3.wav...
#
#
#   Creating midi...
#   💅 Saved to /content/drive/MyDrive/Wire_Note_Project/try_audio_to_sheet/output/musicgen_out-3_basic_pitch.mid
#
# ✨ Done ✨
